# %% [markdown]
# # Coding Question

# %%
import numpy as np

def viterbi(pi, A, B, O):
    """
    Implement the Viterbi algorithm for a discrete Hidden Markov Model (HMM).

    Args:
        pi (numpy.ndarray): Initial state probabilities of shape (N,).
        A (numpy.ndarray): State transition matrix of shape (N, N).
        B (numpy.ndarray): Emission probability matrix of shape (N, M).
        O (list): Observation sequence as a list of integers.

    Returns:
        list: The most likely sequence of hidden states.
        float: The log-probability of the most likely state sequence.
    """



# my approach:
 # 1-get the params: Time steps and len of the observed features "MFCC for example".
  #2- initialize alpha with table of zeros
  #3- for t=0 compute alpha with emmition probability
  #4- for t>=2 compute alpha with another rule due to dynamic programming approach
  #5- take the best score and best state



    T=len(pi)
    N=len(O)  #1

    alpha=np.zeros(len(pi),len(O)) #2

    for i in (N):    #3
      alpha[i][0]=pi*[B[O]]
    #4
    for i in (1,T): # for each time step
      for j in (N): # for each state
        total=0
        for h in (N):

          total+= alpha[t-1][h]*A[h]
        alpha[i][j]=total*B[O[i]]

        best=max(alpha)
        best2=argmax(alpha)



    pass


def initialize_viterbi(pi, B, O):
    """
    Initialize Viterbi dynamic programming tables using log probabilities.

    Args:
        pi (numpy.ndarray): Initial state probabilities.
        B (numpy.ndarray): Emission probability matrix.
        O (list): Observation sequence.

    Returns:
        numpy.ndarray: Initial delta table for t = 0.
        numpy.ndarray: Initial psi table for t = 0.
    """
    pass


def viterbi_step(delta_prev, A, B, observation):
    """
    Perform one Viterbi update step.

    Args:
        delta_prev (numpy.ndarray): Log-probabilities at previous time step.
        A (numpy.ndarray): Transition matrix.
        B (numpy.ndarray): Emission matrix.
        observation (int): Index of current observed symbol.

    Returns:
        numpy.ndarray: Updated delta values for current time step.
        numpy.ndarray: Backpointer values for current step.
    """
    pass


def backtrack(psi, delta_last):
    """
    Backtrack through the psi table to obtain the most likely hidden-state sequence.

    Args:
        psi (numpy.ndarray): Backpointer table for all time steps.
        delta_last (numpy.ndarray): Log-probabilities from the last time step.

    Returns:
        list: The recovered most likely hidden-state sequence.
    """
    pass


def main():
    pi = np.array([0.5, 0.5])
    A = np.array([[0.6, 0.4],
                  [0.2, 0.8]])
    B = np.array([[0.7, 0.2, 0.1],
                  [0.1, 0.3, 0.6]])
    O = [2, 1, 0, 1]

    path, log_prob = viterbi(pi, A, B, O)

    print("Most likely hidden-state sequence:", path)
    print("Log-probability of the sequence:", log_prob)

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-451043146.py in <cell line: 0>()
# ----> 1 main()
#
# /tmp/ipython-input-2364966234.py in main()
#     106     O = [2, 1, 0, 1]
#     107
# --> 108     path, log_prob = viterbi(pi, A, B, O)
#     109
#     110     print("Most likely hidden-state sequence:", path)
#
# /tmp/ipython-input-2364966234.py in viterbi(pi, A, B, O)
#      30     N=len(O)  #1
#      31
# ---> 32     alpha=np.zeros(len(pi),len(O)) #2
#      33
#      34     for i in (N):    #3
#
# TypeError: Cannot interpret '4' as a data type

# %% [markdown]
# # Discusison Question

# %% [markdown]
# when we use the initial way to construct, the time complixity be very high due to O(N^T). then Forward algorithm comes to solve this by using dynamic programming to reuse calculations and reduce the redundancy. the differnece between viterbi and forward is forwrad takes the sum of all probabilities due to hidden states. on other hand, viterbi just take the best "bigger" probability to assign the best path
