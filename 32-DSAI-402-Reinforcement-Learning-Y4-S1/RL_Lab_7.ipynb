# %% [markdown]
# # Optimizing Robot Control Policies Using the Bat Algorithm
# The purpose of this lab is to apply the Bat Algorithm (BA) to a robot path planning problem.
# We will learn how BA can be used to optimize control policies and find efficient paths for a robot navigating a 2D environment represented as a map or grid.

# %% [markdown]
# # Concept Overview:
#
# **Bat Algorithm (BA):**
#
# A metaheuristic inspired by the echolocation behavior of bats.
#
# Each bat represents a potential solution (in this lab: a movement policy for the robot).
#
# Bats adjust their positions (solutions) according to parameters such as frequency, velocity, loudness, and pulse rate to find the optimal path.
#
# **Map Representation:**
#
# The robot environment is modeled as a grid map where:
#
# - 0 → free cell (robot can move)
#
# - 1 → obstacle (blocked cell)
#
#
# **Policy Optimization:**
#
# Each bat’s position encodes a sequence of robot actions (Up, Down, Left, Right).
#
# The algorithm evaluates how well each policy navigates the robot from start to goal without hitting obstacles or going out of bounds.
#
# The fitness function measures the total path cost, considering:
#
# - Step penalties
#
# - Obstacle collisions
#
# - Distance remaining to goal

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import random

def load_or_generate_map(path="map.csv", size=(10, 10), obstacle_prob=0.25, seed=42):
    if os.path.exists(path):
        print(f"✅ Map loaded from '{path}'")
        grid = pd.read_csv(path, header=None).values.astype(int)
    else:
        print("⚙️  Generating new random map and saving to map.csv")
        np.random.seed(seed)
        grid = (np.random.rand(*size) < obstacle_prob).astype(int)
        grid[0, 0] = 0  # start
        grid[-1, -1] = 0  # goal
        pd.DataFrame(grid).to_csv(path, index=False, header=False)
    return grid

# %%
grid = load_or_generate_map()
rows, cols = grid.shape
start = (0, 0)
goal = (rows - 1, cols - 1)

ACTIONS = [(-1, 0), (1, 0), (0, -1), (0, 1)]
ACTION_NAMES = ["↑", "↓", "←", "→"]
# Out:
# ⚙️  Generating new random map and saving to map.csv

# %%
def simulate_policy(actions, grid, start, goal, max_steps=1000):
    pos = np.array(start)
    total_cost = 0
    path = [tuple(pos)]

    # Limit simulation to the length of the policy or max_steps
    # (In this case, policy length is the primary driver)
    for act_idx in actions:
        move = np.array(ACTIONS[int(act_idx) % 4])
        new_pos = pos + move

        # Check bounds & obstacles
        if (0 <= new_pos[0] < grid.shape[0]) and (0 <= new_pos[1] < grid.shape[1]) and (grid[tuple(new_pos)] == 0):
            pos = new_pos
        else:
            # Penalty for hitting a wall or obstacle
            total_cost += 5

        # Cost for taking a step
        total_cost += 1
        path.append(tuple(pos))

        if tuple(pos) == goal:
            break

    # Distance to goal penalty (Manhattan distance)
    dist = np.abs(pos[0] - goal[0]) + np.abs(pos[1] - goal[1])
    total_cost += dist * 2
    return total_cost, path

# %%
def bat_optimize(grid, n_bats=20, n_iter=50, policy_len=40):
    # Initialize bat population (policies)
    bats = np.random.randint(0, 4, (n_bats, policy_len))
    v = np.zeros_like(bats, dtype=float)
    freq_min, freq_max = 0, 2
    loudness = np.ones(n_bats) * 1.5 # Start with higher loudness
    pulse_rate = np.ones(n_bats) * 0.1 # Initial pulse rate
    #pulse_rate_final = 0.85

    def fitness(policy):
        cost, _ = simulate_policy(policy, grid, start, goal)
        return cost

    fitness_vals = np.array([fitness(b) for b in bats]) # initial
    best_idx = np.argmin(fitness_vals)
    best = bats[best_idx].copy()
    best_fit = fitness_vals[best_idx]
    history = [best_fit]

    for t in range(n_iter):
        for i in range(n_bats):
            # Update frequency, velocity, and position
            f = freq_min + (freq_max - freq_min) * np.random.rand()
            v[i] += (bats[i] - best) * f
            new_sol = np.round(bats[i] + v[i]).astype(int) % 4 # Ensure actions are 0-3

            # Local search (random walk)
            if random.random() > pulse_rate[i]:
                eps = np.random.uniform(-1, 1, policy_len)
                # Local search around the current best solution
                new_sol = np.round(best + eps * np.mean(loudness)).astype(int) % 4

            new_fit = fitness(new_sol)

            # Acceptance criteria
            if (new_fit < fitness_vals[i]) and (random.random() < loudness[i]):
                bats[i] = new_sol
                fitness_vals[i] = new_fit
                # Update loudness and pulse rate
                loudness[i] *= 0.9 # Loudness decreases
                pulse_rate[i] = pulse_rate[i] * (1 - np.exp(-0.9 * (t + 1))) # Pulse rate increases

            # Update global best
            if fitness_vals[i] < best_fit:
                best_fit = fitness_vals[i]
                best = bats[i].copy()

        history.append(best_fit)
        if (t + 1) % 10 == 0:
            print(f"Iteration {t + 1}/{n_iter}, Best cost: {best_fit:.2f}")

    return best, best_fit, history

# %%
best_policy, best_cost, hist = bat_optimize(grid = grid , n_bats=60, n_iter=1000, policy_len=80)
print("\nBest cost:", best_cost)
print("Best policy actions (first 20):", [ACTION_NAMES[a] for a in best_policy[:20]])
# Out:
# Iteration 10/1000, Best cost: 140.00
# Iteration 20/1000, Best cost: 140.00
# Iteration 30/1000, Best cost: 114.00
# Iteration 40/1000, Best cost: 114.00
# Iteration 50/1000, Best cost: 104.00
# Iteration 60/1000, Best cost: 104.00
# Iteration 70/1000, Best cost: 104.00
# Iteration 80/1000, Best cost: 104.00
# Iteration 90/1000, Best cost: 104.00
# Iteration 100/1000, Best cost: 104.00
# Iteration 110/1000, Best cost: 104.00
# Iteration 120/1000, Best cost: 104.00
# Iteration 130/1000, Best cost: 104.00
# Iteration 140/1000, Best cost: 70.00
# Iteration 150/1000, Best cost: 70.00
# Iteration 160/1000, Best cost: 70.00
# Iteration 170/1000, Best cost: 70.00
# Iteration 180/1000, Best cost: 70.00
# Iteration 190/1000, Best cost: 70.00
# Iteration 200/1000, Best cost: 70.00
# Iteration 210/1000, Best cost: 70.00
# Iteration 220/1000, Best cost: 70.00
# Iteration 230/1000, Best cost: 70.00
# Iteration 240/1000, Best cost: 70.00
# Iteration 250/1000, Best cost: 70.00
# Iteration 260/1000, Best cost: 70.00
# Iteration 270/1000, Best cost: 70.00
# Iteration 280/1000, Best cost: 70.00
# Iteration 290/1000, Best cost: 70.00
# Iteration 300/1000, Best cost: 70.00
# Iteration 310/1000, Best cost: 70.00
# Iteration 320/1000, Best cost: 70.00
# Iteration 330/1000, Best cost: 70.00
# Iteration 340/1000, Best cost: 70.00
# Iteration 350/1000, Best cost: 70.00
# Iteration 360/1000, Best cost: 70.00
# Iteration 370/1000, Best cost: 70.00
# Iteration 380/1000, Best cost: 70.00
# Iteration 390/1000, Best cost: 70.00
# Iteration 400/1000, Best cost: 70.00
# Iteration 410/1000, Best cost: 70.00
# Iteration 420/1000, Best cost: 70.00
# Iteration 430/1000, Best cost: 70.00
# Iteration 440/1000, Best cost: 64.00
# Iteration 450/1000, Best cost: 64.00
# Iteration 460/1000, Best cost: 64.00
# Iteration 470/1000, Best cost: 64.00
# Iteration 480/1000, Best cost: 64.00
# Iteration 490/1000, Best cost: 64.00
# Iteration 500/1000, Best cost: 64.00
# Iteration 510/1000, Best cost: 64.00
# Iteration 520/1000, Best cost: 64.00
# Iteration 530/1000, Best cost: 64.00
# Iteration 540/1000, Best cost: 64.00
# Iteration 550/1000, Best cost: 64.00
# Iteration 560/1000, Best cost: 64.00
# Iteration 570/1000, Best cost: 64.00
# Iteration 580/1000, Best cost: 64.00
# Iteration 590/1000, Best cost: 64.00
# Iteration 600/1000, Best cost: 64.00
# Iteration 610/1000, Best cost: 64.00
# Iteration 620/1000, Best cost: 64.00
# Iteration 630/1000, Best cost: 62.00
# Iteration 640/1000, Best cost: 62.00
# Iteration 650/1000, Best cost: 52.00
# Iteration 660/1000, Best cost: 52.00
# Iteration 670/1000, Best cost: 52.00
# Iteration 680/1000, Best cost: 52.00
# Iteration 690/1000, Best cost: 52.00
# Iteration 700/1000, Best cost: 52.00
# Iteration 710/1000, Best cost: 52.00
# Iteration 720/1000, Best cost: 52.00
# Iteration 730/1000, Best cost: 52.00
# Iteration 740/1000, Best cost: 52.00
# Iteration 750/1000, Best cost: 52.00
# Iteration 760/1000, Best cost: 52.00
# Iteration 770/1000, Best cost: 52.00
# Iteration 780/1000, Best cost: 52.00
# Iteration 790/1000, Best cost: 42.00
# Iteration 800/1000, Best cost: 42.00
# Iteration 810/1000, Best cost: 42.00
# Iteration 820/1000, Best cost: 42.00
# Iteration 830/1000, Best cost: 42.00
# Iteration 840/1000, Best cost: 42.00
# Iteration 850/1000, Best cost: 42.00
# Iteration 860/1000, Best cost: 42.00
# Iteration 870/1000, Best cost: 42.00
# Iteration 880/1000, Best cost: 42.00
# Iteration 890/1000, Best cost: 42.00
# Iteration 900/1000, Best cost: 42.00
# Iteration 910/1000, Best cost: 42.00
# Iteration 920/1000, Best cost: 42.00
# Iteration 930/1000, Best cost: 42.00
# Iteration 940/1000, Best cost: 42.00
# Iteration 950/1000, Best cost: 42.00
# Iteration 960/1000, Best cost: 42.00
# Iteration 970/1000, Best cost: 42.00
# Iteration 980/1000, Best cost: 42.00
# Iteration 990/1000, Best cost: 42.00
# Iteration 1000/1000, Best cost: 42.00
#
# Best cost: 42
# Best policy actions (first 20): ['→', '←', '←', '→', '↓', '↑', '→', '←', '↓', '→', '↓', '↑', '↓', '→', '↓', '↓', '↑', '↓', '↓', '→']

# %%
cost, path = simulate_policy(best_policy, grid, start, goal)
print("\nOptimized robot path (first 20 steps):", path[:20])

# Visualization
plt.figure(figsize=(8, 8))
# Create a colormap: 0=white, 1=black
cmap = plt.cm.colors.ListedColormap(['white', 'black'])
plt.imshow(grid, cmap=cmap, interpolation='nearest')

path = np.array(path)
plt.plot(path[:, 1], path[:, 0], 'r-o', markersize=4, label='Path')
plt.scatter(start[1], start[0], c='blue', s=120, label='Start', zorder=5)
plt.scatter(goal[1], goal[0], c='green', s=120, label='Goal', zorder=5)

# Set ticks to be at the center of the cells
ax = plt.gca()
ax.set_xticks(np.arange(-.5, grid.shape[1], 1), minor=True)
ax.set_yticks(np.arange(-.5, grid.shape[0], 1), minor=True)
ax.grid(which='minor', color='grey', linestyle='-', linewidth=0.5)
ax.set_xticks([])
ax.set_yticks([])

plt.legend()
plt.title(f"Best Path Found by Bat Algorithm (Cost: {best_cost})")
plt.show()
# Out:
# Optimized robot path (first 20 steps): [(np.int64(0), np.int64(0)), (np.int64(0), np.int64(1)), (np.int64(0), np.int64(0)), (np.int64(0), np.int64(0)), (np.int64(0), np.int64(1)), (np.int64(1), np.int64(1)), (np.int64(0), np.int64(1)), (np.int64(0), np.int64(2)), (np.int64(0), np.int64(1)), (np.int64(1), np.int64(1)), (np.int64(1), np.int64(2)), (np.int64(2), np.int64(2)), (np.int64(1), np.int64(2)), (np.int64(2), np.int64(2)), (np.int64(2), np.int64(3)), (np.int64(3), np.int64(3)), (np.int64(4), np.int64(3)), (np.int64(3), np.int64(3)), (np.int64(4), np.int64(3)), (np.int64(5), np.int64(3))]

# %%
plt.figure()
plt.plot(hist)
plt.title("Bat Algorithm Convergence (Path Cost)")
plt.xlabel("Iteration")
plt.ylabel("Best Cost")
plt.grid(True)
plt.show()
