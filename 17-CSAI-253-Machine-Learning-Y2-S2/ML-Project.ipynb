# %% [markdown]
# # **ML Project: (Comparative Analysis of Machine Learning Models for Activity Recognition using MHEALTH Dataset)**

# %% [markdown]
# # In this Project I'll build 5 ML models:
#
# 1-KNN: it's not fully models, it's just a function to classifying the data "unsupervised  learning"
#
# ---
#
#
#
# 2-Linear Regression
#
# 3-SVM
#
# 4-NN
#
# 5-Logistic Regression for activity recognition.

# %% [markdown]
# #Firstly, I'll download all libraries that I'll use and import MHEALTH Dataset:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("mhealth_raw_data.csv")
df
# Out:
# <ipython-input-2-934ef29300a4>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("mhealth_raw_data.csv")
#             alx      aly      alz       glx      gly      glz      arx  \
# 0      2.184900  -9.6967  0.63077  0.103900 -0.84053 -0.68762 -8.64990
# 1      2.387600  -9.5080  0.68389  0.085343 -0.83865 -0.68369 -8.62750
# 2      2.408600  -9.5674  0.68113  0.085343 -0.83865 -0.68369 -8.50550
# 3      2.181400  -9.4301  0.55031  0.085343 -0.83865 -0.68369 -8.62790
# 4      2.417300  -9.3889  0.71098  0.085343 -0.83865 -0.68369 -8.70080
# ...         ...      ...      ...       ...      ...      ...      ...
# 79878 -0.008991  -7.9974 -0.73329 -0.319110 -0.79925 -0.47348  1.21220
# 79879  5.050100 -17.8260  3.51340 -0.319110 -0.79925 -0.47348 -1.31310
# 79880  2.492500  -8.7460 -1.32900 -0.319110 -0.79925 -0.47348 -0.53513
# 79881  0.613110 -14.4860  0.90683 -0.374770 -0.70544 -0.48330  1.22400
# ...

# %% [markdown]
# # KNN Algorithm
# > 1. Calculate the distances between all the training data and the test point.<img src="https://www.kdnuggets.com/wp-content/uploads/popular-knn-metrics-1.png" align = 'center'>
# > 2. Find the nearest K neighbors by sorting these pairwise distances.
# > 3. Classify the point based on a majority vote.

# %%
from collections import Counter

from sklearn.metrics import accuracy_score

# %%
X = df.drop(['Activity', 'subject'], axis=1)[:100_00]
y = df.Activity[:100_00] #selects the first 100,00 rows from the Activity column

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, random_state=42, test_size=0.4)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)
knn.score(X_test_scaled, y_test), knn.score(X_train_scaled, y_train)
# Out:
# (0.9285, 0.9551666666666667)

# %%
plt.figure(figsize=(12, 9))
plt.plot(neighbors, train_accuracies, label="Training Accuracy")
plt.plot(neighbors, test_accuracies, label = "Test Accuracy")
plt.title("KNN: Varying Number of Neighbors")
plt.legend()
plt.xlabel("Neighbors")
plt.ylabel("Accuracy")
plt.grid(True, which='both', axis='both', linestyle='-', linewidth=0.5)
plt.xticks(ticks=neighbors)
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train_scaled, y_train)
knn.score(X_test_scaled, y_test), knn.score(X_train_scaled, y_train)
# Out:
# (0.931, 0.9498333333333333)

# %%
plt.figure(figsize=(12, 9))
plt.plot(neighbors, train_accuracies, label="Training Accuracy")
plt.plot(neighbors, test_accuracies, label = "Test Accuracy")
plt.title("KNN: Varying Number of Neighbors")
plt.legend()
plt.xlabel("Neighbors")
plt.ylabel("Accuracy")
plt.grid(True, which='both', axis='both', linestyle='-', linewidth=0.5)
plt.xticks(ticks=neighbors)
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train_scaled, y_train)
knn.score(X_test_scaled, y_test), knn.score(X_train_scaled, y_train)
# Out:
# (0.926, 0.9493333333333334)

# %%
plt.figure(figsize=(12, 9))
plt.plot(neighbors, train_accuracies, label="Training Accuracy")
plt.plot(neighbors, test_accuracies, label = "Test Accuracy")
plt.title("KNN: Varying Number of Neighbors")
plt.legend()
plt.xlabel("Neighbors")
plt.ylabel("Accuracy")
plt.grid(True, which='both', axis='both', linestyle='-', linewidth=0.5)
plt.xticks(ticks=neighbors)
plt.show()

# %%
from sklearn.metrics import accuracy_score
train_accuracies = []
test_accuracies = []
neighbors = range(1, 10)
for neighbor in neighbors:
    knn = KNeighborsClassifier(n_neighbors=neighbor)
    knn.fit(X_train, y_train)

    y_pred_train = knn.predict(X_train)
    train_accuracies.append(accuracy_score(y_pred_train, y_train))

    y_pred_test = knn.predict(X_test)
    test_accuracies.append(accuracy_score(y_pred_test, y_test))

# %%
plt.figure(figsize=(12, 9))
plt.plot(neighbors, train_accuracies, label="Training Accuracy")
plt.plot(neighbors, test_accuracies, label = "Test Accuracy")
plt.title("KNN: Varying Number of Neighbors")
plt.legend()
plt.xlabel("Neighbors")
plt.ylabel("Accuracy")
plt.grid(True, which='both', axis='both', linestyle='-', linewidth=0.5)
plt.xticks(ticks=neighbors)
plt.show()

# %% [markdown]
# #**Linear Regression:**
#
# Y=XW

# %%
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression().fit(X_train, y_train)
regression.score(X_train, y_train), regression.score(X_test, y_test)
# Out:
# (0.25841964232269854, 0.25951805633293745)

# %%
Polynomial = PolynomialFeatures(2)
X_train2 = Polynomial.fit_transform(X_train)
X_test2 = Polynomial.fit_transform(X_test)

regression2 = LinearRegression().fit(X_train2, y_train)
regression2.score(X_train2, y_train), regression2.score(X_test2, y_test)
# Out:
# (0.5886943421180969, 0.6123760837182656)

# %% [markdown]
# #**SVM:**

# %%
from mlxtend.plotting import plot_decision_regions
from sklearn.svm import SVC

# %%
SVM = SVC(C=5, kernel='rbf', gamma=0.5)   #Best one because the data is with high dimensions

SVM.fit(X_train, y_train.ravel())
y_pred = SVM.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print(f'Accuracy with " rbf " kernel: {accuracy:.2f}')
# Out:
# Accuracy with " rbf " kernel: 0.95

# %%
SVM = SVC(C=5, kernel='linear', gamma=0.5)

SVM.fit(X_train, y_train.ravel())
y_pred = SVM.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print(f'Accuracy with " rbf " kernel: {accuracy:.2f}')
# Out:
# Accuracy with " rbf " kernel: 0.83

# %%
SVM = SVC(C=5, kernel='poly', gamma=0.5) #higher-dimensional

SVM.fit(X_train, y_train.ravel())
y_pred = SVM.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print(f'Accuracy with " rbf " kernel: {accuracy:.2f}')
# Out:
# Accuracy with " rbf " kernel: 0.94

# %%
SVM = SVC(C=5, kernel='sigmoid', gamma=0.5)

SVM.fit(X_train, y_train.ravel())
y_pred = SVM.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print(f'Accuracy with " rbf " kernel: {accuracy:.2f}')
# Out:
# Accuracy with " rbf " kernel: 0.37

# %% [markdown]
# y_pred = SVM.predict(X_test)
#
# accuracy = accuracy_score(y_test, y_pred)
#
# print(f'Accuracy with " rbf " kernel: {accuracy:.2f}')

# %% [markdown]
# ## Neural Network

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from keras.models import Sequential
from keras.layers import Dense

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense #makes summation, activation
import matplotlib.pyplot as plt
from keras.optimizers import SGD, Adam

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, y, test_size=0.3, random_state=1)
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5, random_state=1)
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (7000, 12) (1500, 12) (1500, 12) (7000,) (1500,) (1500,)

# %%
model = Sequential([
    Dense(10, activation='relu', input_shape=(10,)), #vector
    Dense(5, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(32, input_shape=(12,), activation='relu'))  # Adjust input shape to match your data
# Add more layers as needed
model.add(Dense(1, activation='sigmoid'))  # Example output layer

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(X_train, Y_train,
          batch_size=32,epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 3131/3131 [==============================] - 13s 4ms/step - loss: nan - accuracy: 0.3715 - val_loss: nan - val_accuracy: 0.7762
# Epoch 2/100
# 3131/3131 [==============================] - 10s 3ms/step - loss: nan - accuracy: 0.7757 - val_loss: nan - val_accuracy: 0.7762
# Epoch 3/100
# 3131/3131 [==============================] - 9s 3ms/step - loss: nan - accuracy: 0.7757 - val_loss: nan - val_accuracy: 0.7762
# Epoch 4/100
# 3131/3131 [==============================] - 8s 3ms/step - loss: nan - accuracy: 0.7757 - val_loss: nan - val_accuracy: 0.7762
# Epoch 5/100
# 3131/3131 [==============================] - 7s 2ms/step - loss: nan - accuracy: 0.7757 - val_loss: nan - val_accuracy: 0.7762
# Epoch 6/100
# 3131/3131 [==============================] - 7s 2ms/step - loss: nan - accuracy: 0.7757 - val_loss: nan - val_accuracy: 0.7762
# Epoch 7/100
# ...

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
model = Sequential([
    Dense(10, activation='relu', input_shape=(10,)), #vector
    Dense(5, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model.compile(optimizer='Adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(32, input_shape=(12,), activation='relu'))  # Adjust input shape to match your data
# Add more layers as needed
model.add(Dense(1, activation='sigmoid'))  # Example output layer

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(X_train, Y_train,
          batch_size=32,epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 219/219 [==============================] - 2s 4ms/step - loss: 0.6045 - accuracy: 0.6803 - val_loss: 0.5554 - val_accuracy: 0.7047
# Epoch 2/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.5232 - accuracy: 0.6917 - val_loss: 0.4858 - val_accuracy: 0.7027
# Epoch 3/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4651 - accuracy: 0.6879 - val_loss: 0.4391 - val_accuracy: 0.6980
# Epoch 4/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4233 - accuracy: 0.7489 - val_loss: 0.4057 - val_accuracy: 0.9047
# Epoch 5/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3923 - accuracy: 0.8490 - val_loss: 0.3787 - val_accuracy: 0.9007
# Epoch 6/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3670 - accuracy: 0.8943 - val_loss: 0.3607 - val_accuracy: 0.8593
# Epoch 7/100
# ...

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
data = pd.read_csv("mhealth_raw_data.csv")  # Update the file path as needed
X = data.drop(['Activity', 'subject'], axis=1)
y = data['Activity']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


encoder = OneHotEncoder()
y_encoded = encoder.fit_transform(y.values.reshape(-1, 1))
y_encoded_dense = y_encoded.toarray()


X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded_dense, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Dense(64, input_dim=X_train.shape[1], activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f'Test accuracy: {test_acc:.4f}')
# Out:
# Epoch 1/10
# 3578/3578 [==============================] - 16s 3ms/step - loss: nan - accuracy: 0.7822
# Epoch 2/10
# 3578/3578 [==============================] - 9s 3ms/step - loss: nan - accuracy: 0.7761
# Epoch 3/10
# 3578/3578 [==============================] - 17s 5ms/step - loss: nan - accuracy: 0.7761
# Epoch 4/10
# 3578/3578 [==============================] - 15s 4ms/step - loss: nan - accuracy: 0.7761
# Epoch 5/10
# 3578/3578 [==============================] - 12s 3ms/step - loss: nan - accuracy: 0.7761
# Epoch 6/10
# 3578/3578 [==============================] - 9s 3ms/step - loss: nan - accuracy: 0.7761
# Epoch 7/10
# 3578/3578 [==============================] - 15s 4ms/step - loss: nan - accuracy: 0.7761
# Epoch 8/10
# 3578/3578 [==============================] - 17s 5ms/step - loss: nan - accuracy: 0.7761
# Epoch 9/10
# 3578/3578 [==============================] - 21s 6ms/step - loss: nan - accuracy: 0.7761
# Epoch 10/10
# ...

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
hist = model.fit(X_train, y_train, epochs=5, batch_size=10, validation_split=0.2)
# Out:
# Epoch 1/5
# 9159/9159 [==============================] - 26s 3ms/step - loss: nan - accuracy: 1.0000 - val_loss: nan - val_accuracy: 1.0000
# Epoch 2/5
# 9159/9159 [==============================] - 26s 3ms/step - loss: nan - accuracy: 1.0000 - val_loss: nan - val_accuracy: 1.0000
# Epoch 3/5
# 9159/9159 [==============================] - 23s 3ms/step - loss: nan - accuracy: 1.0000 - val_loss: nan - val_accuracy: 1.0000
# Epoch 4/5
# 9159/9159 [==============================] - 28s 3ms/step - loss: nan - accuracy: 1.0000 - val_loss: nan - val_accuracy: 1.0000
# Epoch 5/5
# 9159/9159 [==============================] - 28s 3ms/step - loss: nan - accuracy: 1.0000 - val_loss: nan - val_accuracy: 1.0000

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay

# %%
data = pd.read_csv("mhealth_raw_data.csv")
data = df.fillna(222222)

X = data.drop(['Activity', 'subject'] , axis=1)
y = data['Activity']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-4b33141f1945> in <cell line: 7>()
#       5 y = data['Activity']
#       6
# ----> 7 X_scaled = scaler.fit_transform(X)
#       8
#       9
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# --> 878             return self.fit(X, **fit_params).transform(X)
#     879         else:
# ...

# %%
# to use One Vs Rest algorithm, set > multi_class='ovr'

classifier = LogisticRegression(multi_class='ovr', solver='liblinear', max_iter=1000)

classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000, multi_class='ovr', solver='liblinear')

# %%
y_pred=classifier.predict(X_test)

print(accuracy_score(y_test,y_pred))
# Out:
# 0.7840472363915869

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.99      0.88     22154
#          1.0       0.00      0.00      0.00       579
#          2.0       0.00      0.00      0.00       631
#          3.0       0.72      0.73      0.73       623
#          4.0       0.00      0.00      0.00       655
#          6.0       0.00      0.00      0.00       611
#          7.0       0.00      0.00      0.00       617
#          8.0       0.00      0.00      0.00       687
#          9.0       0.00      0.00      0.00       600
#         10.0       0.00      0.00      0.00       662
#         11.0       0.00      0.00      0.00       606
#         12.0       0.00      0.00      0.00       197
#
#     accuracy                           0.78     28622
#    macro avg       0.13      0.14      0.13     28622
# weighted avg       0.62      0.78      0.69     28622
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

fig, ax = plt.subplots(figsize=(8,6), dpi=100)

# initialize using the raw 2D confusion matrix
# and output labels (in our case, it's 0 and 1)
display = ConfusionMatrixDisplay(conf_matrix, display_labels=classifier.classes_)

# set the plot title using the axes object
ax.set(title='Confusion Matrix for the Diabetes Detection Model')
display.plot(ax=ax);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-170c1402f4fd> in <cell line: 12>()
#      10 # set the plot title using the axes object
#      11 ax.set(title='Confusion Matrix for the Diabetes Detection Model')
# ---> 12 display.plot(ax=ax);
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_plot/confusion_matrix.py in plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     179         if colorbar:
#     180             fig.colorbar(self.im_, ax=ax)
# --> 181         ax.set(
#     182             xticks=np.arange(n_classes),
#     183             yticks=np.arange(n_classes),
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in <lambda>(self, **kwargs)
#     145             return
#     146
# --> 147         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
# ...
