# %% [markdown]
# # Lab Practice (1) -  **Machine** **Learning**
#
# **This Lab objective:**
#
#
# *   Review on Numpyy - Pandas Libraries.
# *   Review on Data Cleaning / Preprocessing.
#
#
# **Recommended Sources:**
#
# *   Numpy: https://www.w3schools.com/python/numpy/default.asp
# *   Pandas: https://www.w3schools.com/python/pandas/default.asp
#
#  **On the Classrom:**
# *   Notebook: Revision- Numpy/pandas + pdf file
# *   Notebook: Revision- Data Visualization

# %% [markdown]
# # Data Preprcossing:
# *   Imporove Data Quality.
# *   Prepare the data for any further analysis (ML model).
#
#
#
#
# 1. **Handling missing data:** Incomplete data is a common problem. Data Preprocessing provides a strategy to address missing values and avoid interruptions in the analysis.
# 2. **Handling outliers:** Data Preprocessing provides techniques to effectively detect and manage outliers.
# 3. **Remove duplicates:** Duplicate entries can distort your analysis results. Data preprocessing includes identifying and removing duplicate data points.
# 4. **Encoding Categorical Variables:** Most of used algorithms typically require numerical inputs. Data Preprocessing provides a way to convert categorical data to numerical format.

# %% [markdown]
# ## House Sales Prediction
#
# #### Feature Columns
#
# * **id** - Unique ID for each home sold
# * **date** - Date of the home sale
# * **price** - Price of each home sold
# * **bedrooms** - Number of bedrooms
# * **bathrooms** - Number of bathrooms, where .5 accounts for a room with a toilet but no shower
# * **sqft_living** - Square footage of the apartments interior living space
# * **sqft_lot** - Square footage of the land space
# * **floors** - Number of floors
# * **waterfront** - A dummy variable for whether the apartment was overlooking the waterfront or not
# * **view** - An index from 0 to 4 of how good the view of the property was
# * **condition** - An index from 1 to 5 on the condition of the apartment,
# * **grade** - An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
# * **sqft_above** - The square footage of the interior housing space that is above ground level
# * **sqft_basement** - The square footage of the interior housing space that is below ground level
# * **yr_built** - The year the house was initially built
# * **yr_renovated** - The year of the house’s last renovation
# * **zipcode** - What zipcode area the house is in
# * **lat** - Lattitude
# * **long** - Longitude
# * **sqft_living15** - The square footage of interior housing living space for the nearest 15 neighbors
# * **sqft_lot15** - The square footage of the land lots of the nearest 15 neighbors
#
#
# Data used: https://www.kaggle.com/harlfoxem/housesalesprediction

# %%
#import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the csv file
df = pd.read_csv('/content/kc_house_data.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
#return the firt 5 dataset row
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    floors  waterfront  view  condition  ...  yr_built  yr_renovated  zipcode  \
# 0     1.0           0     0          3  ...      1955             0    98178
# 1     2.0           0     0          3  ...      1951          1991    98125
# 2     1.0           0     0          3  ...      1933             0    98028
# 3     1.0           0     0          5  ...      1965             0    98136
# 4     1.0           0     0          3  ...      1987             0    98074
#
# ...

# %%
df.tail(5)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  floors  waterfront  view  condition  ...  yr_built  \
# 21608         1530     3.0           0     0          3  ...      2009
# 21609         2310     2.0           0     0          3  ...      2014
# 21610         1020     2.0           0     0          3  ...      2009
# 21611         1600     2.0           0     0          3  ...      2004
# 21612         1020     2.0           0     0          3  ...      2008
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
#dataset columns
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'sqft_lot',
#        'sqft_above', 'sqft_basement'],
#       dtype='object')

# %%
#get some information about our DataSet
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  yr_built       21613 non-null  int64
#  12  yr_renovated   21613 non-null  int64
#  13  zipcode        21613 non-null  int64
#  14  lat            21613 non-null  float64
#  15  long           21613 non-null  float64
#  16  sqft_living15  21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
# let's drop unnecessary featurs
df.drop('id',axis=1,inplace=True)

# %%
df.drop('zipcode',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'yr_built', 'yr_renovated',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'sqft_lot', 'sqft_above',
#        'sqft_basement'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 1- Handling Missing Data

# %%
# check if there are any Null values
df.isnull()
# Out:
#         date  price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0      False  False     False      False        False   False       False
# 1      False  False     False      False        False   False       False
# 2      False  False     False      False        False   False       False
# 3      False  False     False      False        False   False       False
# 4      False  False     False      False        False   False       False
# ...      ...    ...       ...        ...          ...     ...         ...
# 21608  False  False     False      False        False   False       False
# 21609  False  False     False      False        False   False       False
# 21610  False  False     False      False        False   False       False
# 21611  False  False     False      False        False   False       False
# 21612  False  False     False      False        False   False       False
#
#         view  condition  grade  yr_built  yr_renovated    lat   long  \
# ...

# %%
# check if there are any Null values
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# yr_built         0
# yr_renovated     0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# sqft_lot         0
# sqft_above       0
# sqft_basement    0
# dtype: int64

# %%
#remove rows with missing values / HERE no missing values
#data_cleaned=df.dropna()
#print(data_cleaned)
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  floors  \
# 0      20141013T000000  221900.0         3       1.00         1180     1.0
# 1      20141209T000000  538000.0         3       2.25         2570     2.0
# 2      20150225T000000  180000.0         2       1.00          770     1.0
# 3      20141209T000000  604000.0         4       3.00         1960     1.0
# 4      20150218T000000  510000.0         3       2.00         1680     1.0
# ...                ...       ...       ...        ...          ...     ...
# 21608  20140521T000000  360000.0         3       2.50         1530     3.0
# 21609  20150223T000000  400000.0         4       2.50         2310     2.0
# 21610  20140623T000000  402101.0         2       0.75         1020     2.0
# 21611  20150116T000000  400000.0         3       2.50         1600     2.0
# 21612  20141015T000000  325000.0         2       0.75         1020     2.0
#
# ...

# %% [markdown]
# ## Let's Do some Visulization to see Data insights

# %%
#visualizing house prices
plt.figure(figsize=(10,7))
plt.hist(df['price'])
# Out:
# (array([1.9021e+04, 2.1420e+03, 3.2200e+02, 9.0000e+01, 2.6000e+01,
#         4.0000e+00, 4.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([  75000.,  837500., 1600000., 2362500., 3125000., 3887500.,
#         4650000., 5412500., 6175000., 6937500., 7700000.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 2-Check the Outlier

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
#visualizing bedrooms, bathrooms, floors,grades
plt.figure(figsize=(15,7))
sns.countplot(x=df['bedrooms'], palette = 'Greens_d')
# Out:
# <ipython-input-26-190ae8a89599>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['bedrooms'], palette = 'Greens_d')
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
sns.countplot(x=df['floors'])
# Out:
# <Axes: xlabel='floors', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(x=df['bathrooms'])
# Out:
# <Axes: xlabel='bathrooms', ylabel='count'>

# %%
sns.countplot(x=df['grade'])
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
#visualizing square footage of (home,lot,above and basement)
fig = plt.figure(figsize=(16,5))
sns.scatterplot(x=df['sqft_above'], y=df['price'])
# Out:
# <Axes: xlabel='sqft_above', ylabel='price'>

# %%
sns.scatterplot(x=df['sqft_lot'],y=df['price'])
# Out:
# <Axes: xlabel='sqft_lot', ylabel='price'>

# %%
sns.scatterplot(x=df['sqft_living'],y=df['price'])
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
sns.scatterplot(x=df['sqft_basement'],y=df['price'])
# Out:
# <Axes: xlabel='sqft_basement', ylabel='price'>

# %%
df.corr()
# Out:
# <ipython-input-34-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   price  bedrooms  bathrooms  sqft_living    floors  \
# price          1.000000  0.308338   0.525134     0.702044  0.256786
# bedrooms       0.308338  1.000000   0.515884     0.576671  0.175429
# bathrooms      0.525134  0.515884   1.000000     0.754665  0.500653
# sqft_living    0.702044  0.576671   0.754665     1.000000  0.353949
# floors         0.256786  0.175429   0.500653     0.353949  1.000000
# waterfront     0.266331 -0.006582   0.063744     0.103818  0.023698
# view           0.397346  0.079532   0.187737     0.284611  0.029444
# condition      0.036392  0.028472  -0.124982    -0.058753 -0.263768
# grade          0.667463  0.356967   0.664983     0.762704  0.458183
# ...

# %%
# check correlation
df.corr()['price'].sort_values(ascending=False)
# Out:
# <ipython-input-35-6decc3f26d34>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['price'].sort_values(ascending=False)
# price            1.000000
# sqft_living      0.702044
# grade            0.667463
# sqft_above       0.605566
# sqft_living15    0.585374
# bathrooms        0.525134
# view             0.397346
# sqft_basement    0.323837
# bedrooms         0.308338
# lat              0.306919
# waterfront       0.266331
# floors           0.256786
# yr_renovated     0.126442
# sqft_lot         0.089655
# sqft_lot15       0.082456
# yr_built         0.053982
# condition        0.036392
# long             0.021571
# Name: price, dtype: float64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-36-c81e52776797>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
# feature with higher correlation
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
# feature like number of bedroom or bathroom
plt.figure(figsize = (10,8))
sns.boxplot(x = 'bedrooms',y = 'price', data = df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
# feature like number of bedroom or bathroom
plt.figure(figsize = (10,8))
sns.boxplot(x = 'bathrooms',y = 'price', data = df)
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %% [markdown]
# # **NOW it's your TURN**

# %% [markdown]
# 1- Scenario:
# You are tasked with preparing the **Titanic dataset** for analysis in a research project.
#
# The dataset contains information about passengers aboard the Titanic, including features such as age, sex, ticket class, and survival status. However, the dataset is **incomplete, with missing values and potential duplicates**. Your goal is to clean and prepare the dataset for further analysis.
#
# - Look at the whole dataset, No of rows/columns, check data types, data information.
# - Check for duplicates or null data
# - Do some analysis to uderstand our data more; you can do  by using plots.

# %%
#import libraries

# %%
#read dataset


# return the fist 5 rows

# %%
# return the last 5 rows

# %%
#check the shape of the dataset

# %%
# return colums names

# %%
#check the dataset information (the coloums non-missing values and coloums data types)

# %%
#return some statistics regarding the data

# %%
# return number of unique elements in the object for each coloum

# %%
#return the age column only

# %%
#return the age / survived columns

# %%
#filter data based on this condidtion (the survived equal 1)

# %%
# return the first row of dataframe

# %%
# return the first column of data frame

# %%
# return the first two columns of data frame with all rows

# %%
#check for duplicates / remove it

# %%
# count the number of missing values in each column

# %%
#plot a bar plot to show the missing values

# %%
#check is there any outliers

# %%
# you would like to know if the output follows a normal distribution
# a simple way to know the distribution by using the visualization tools
#for the Age columns check its distribution

# %% [markdown]
# # 2- Scenario : **Data Analysis on Employee Information**
# You have a dataset containing employee information.
#
# * **a.Load the Dataset:**
# Load the dataset named Employee_Salary_Dataset.csv into a Pandas DataFrame.
# <br>#dataset Ref :https://www.kaggle.com/datasets/anninasimon/employee-salary-dataset
# * **b.Display Basic Information:**
# Display the first 10 rows, last 10 rows and the basic information (data types, non-null counts) of the DataFrame.
#
# * **c.Calculate Statistics:**
# Calculate the mean, median, and standard deviation of the 'Salary' column.
#
# * **d.Filtering and Sorting:**
# Filter the employees earning more than $80,000 and sort them in descending order of salary.
#
# * **c.Grouping and Aggregation:**
# Group the data by 'Department' and calculate the average salary for each department.

# %%
### Sol of Scenario 2: Data Analysis on Employee Information
import pandas as pd

# Load the dataset into a Pandas DataFrame

## continue here..
