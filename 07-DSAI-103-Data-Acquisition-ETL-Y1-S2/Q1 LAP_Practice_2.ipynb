# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
l=np.array([(-31.75, -22.61, -150.88),
(-29.72, -33.02, -156.46),
(62.48, -56.39, -88.14),
(53.34, -66.55, -90.42),
(20.07, 18.29, -33.53),
(26.16, 31.50, -37.34)])

# %%
for i in range (len (l)):

  tot_x+=l[i][0]
  tot_y+=l[i][1]
  tot_z+=l[i][2]


print(tot_x)
print(tot_y)
print(tot_z)
# Out:
# 26.16
# 31.5
# -37.34

# %%
dist=[(tot_x/6,tot_y/6,tot_z/6)]
print(dist)
# Out:
# [(4.36, 5.25, -6.223333333333334)]
