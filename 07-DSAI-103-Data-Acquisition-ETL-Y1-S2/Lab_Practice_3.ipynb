# %%
# !pip install google
# !pip install google-search-results
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32002 sha256=70c6a7a337eb6cd61b35dc92d2631db211cb1d7ff1cc681dea074a18d80cc4c0
#   Stored in directory: /root/.cache/pip/wheels/d3/b2/c3/03302d12bb44a2cdff3c9371f31b72c0c4e84b8d2285eeac53
# Successfully built google-search-results
# ...

# %%
from serpapi import GoogleSearch
import requests

# %%
import cv2

# %%
params = {
"api_key" : 'cb37586e2a8d129c4142b06c3d46a19aa8bb11187c776a85977298893a5a3266',
"q": " Police car sprite sheet",
"google_domain": "google.com",
"tbm": "isch", 
}
search = GoogleSearch(params)
results = search.get_dict()

# %%
res = results['images_results']
print(res)
# Out:
# [{'position': 1, 'thumbnail': 'https://serpapi.com/searches/646f2d7714b245c119c8c460/images/c77acb68199848bb2b6402587d32ea3f75dd2ca902f87482371708b708950b21.jpeg', 'related_content_id': 'NU9jbm1zTVNiYzlzb01cIixcInhLOFhGeHIzdlU5MUFN', 'serpapi_related_content_link': 'https://serpapi.com/search.json?engine=google_images_related_content&gl=us&hl=en&q=+Police+car+sprite+sheet&related_content_id=NU9jbm1zTVNiYzlzb01cIixcInhLOFhGeHIzdlU5MUFN', 'source': 'PNGkit', 'title': 'Police Car Sprite Sheet - 872x872 PNG Download - PNGkit', 'link': 'https://www.pngkit.com/view/u2e6r5r5e6e6a9e6_police-car-sprite-sheet/', 'original': 'https://www.pngkit.com/png/detail/397-3971373_police-car-sprite-sheet.png', 'original_width': 820, 'original_height': 750, 'is_product': False}, {'position': 2, 'thumbnail': 'https://serpapi.com/searches/646f2d7714b245c119c8c460/images/c77acb68199848bb42c77476bb7a8c6df6f2365b34f1ca21cc8fc7dc1fd576a2.jpeg', 'related_content_id': 'MjJGVC1KcFNJVDB5OU1cIixcIlMwNFE3RTFubzdDMGRN
# ...

# %%
for i in range(len(res)+1):
  print(res[i]["original"]) 
  r4 = requests.get(res[i]["original"])
  print(r4)
  if i>20:
      break
  img_data2 = r4.content
  name = "car_sprite_"+ str(i)+"0"+ str(i)+".jpg"
  with open(name, 'wb') as handler: 
       handler.write(img_data2)
# Out:
# https://www.pngkit.com/png/detail/397-3971373_police-car-sprite-sheet.png
# <Response [200]>
# https://w7.pngwing.com/pngs/1003/52/png-transparent-police-car-sprite-vehicle-2d-computer-graphics-car-truck-car-vehicle.png
# <Response [200]>
# https://opengameart.org/sites/default/files/SMS_Touring_Police_Car_Sprite_Sheet.png
# <Response [200]>
# https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/ef2c82eb-ab3b-4bdb-88ad-5bae9c705695/ddwov6c-b0972a31-fa41-4d12-a6ae-1191273dc533.png?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..v4Fz7akARICIXiP8HBAO0RPJ1yHCMCiusYvRvbMz0jU
# <Response [200]>
# ...

# %%
image = cv.imread('car_sprite_404.jpg')
img2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
plt.imshow(img2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-deda24090969> in <cell line: 1>()
# ----> 1 image = cv.imread('car_sprite_404.jpg')
#       2 img2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#       3 plt.imshow(img2)
#
# NameError: name 'cv' is not defined

# %%
x_add = 225
y_add = 220

crops = []
x = 0
y = 0
for i in range(4):
  for j in range(4):
    t = img2[y:y+ y_add , x:x+ x_add]
    crops.append(t)
    x += x_add
  y += y_add
  x = 0
  
  
fig = plt.figure()
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for i in range(16): 

    plt.subplot(4 , 4, i+1)
    plt.imshow(crops[i])
plt.show()

# %%
points = "carmodel.txt"
points = []
