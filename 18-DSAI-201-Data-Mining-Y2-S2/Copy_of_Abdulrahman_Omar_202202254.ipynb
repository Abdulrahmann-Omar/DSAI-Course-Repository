# %% [markdown]
# <h1><center></center></h1>
# <h1><center>DSAI 201</center></h1>
# <h1><center>Lab Exam 1 </center></h1>
# <h2><center>Model D</center></h2>
# <h2><center>Exam Time: 60 minutes</center></h2>

# %% [markdown]
# **Exam Instructions**
# - You are allowed to open **Pyterrir & SKlearn & NLTK documentation**, no other links or Colabs. Any form of cheating will result in a **ZERO GRADE**.
#
# - **Disable AI assistance** tools during the exam.
#
# - **Close all** unnecessary browser tabs and windows.
#
# - Keep **your phone away** and on silent mode.
#
# ---

# %% [markdown]
# 1. [PyTerrier Documentation](https://pyterrier.readthedocs.io/en/latest/?authuser=0)
# 2. [SkLearn Documentation](https://scikit-learn.org/stable/api/index.html?authuser=0)
# 3. [NLTK Documentation](https://www.nltk.org/?authuser=0)

# %% [markdown]
# ### **Lab Exam 1: Book Recommendation & Information Retrieval on Books Dataset**
# ---
# ### **📌 Overview**
# In this exam, you will work with [Books Dataset](https://docs.google.com/spreadsheets/d/1CsHU2LBuxlckPZD1EiOL0TV21XV3DGo5m9cj8ZpFy4A/edit?usp=sharing)**,  📌 focusing on:**
#
#
# - **Preprocessing** text data
# - **Indexing and searching** reviews using PyTerrier
# - Performing **Content-Based Recommendation** on book category
# ---
#
# ### **📝 Tasks**
#
# ### **🔹 Part 1: Data Preprocessing**
#
# - Load the dataset and **keep only relevant columns**:
# ```
# title
# categories
# description
# ```
# - **Preprocess the text** :
#    - Convert to lowercase
#    - Remove punctuation, parentheses\brackets, and URLs
#    - Tokenization & lemmatization
#    - Remove stopwords.
# ---
#
# ### **🔹 Part 2: Indexing with PyTerrier**
#  Create an index for **description** using PyTerrier:
# ---
#
# ### **🔹 Part 3: Querying & Retrieval**
#
# ###   1- Execute the following **search queries** using the function search_term() for the following queries:
#
#    - "Theory of Relativity"
#    - "love story"
#    - "motive"
#
# ### 2- Find the **most frequently occurring word** in 'description'.
# ---
#
# ### **🔹 Part 4: Book Recommendation**
# - Define a list of available book categories
# - Implement a function to **recommend_book** that takes query string (user's prompt) and recommend books based on user's prompt\intent. use Regular Expressions
# - Display **result** of recommendation on two queries.
# ---

# %%
from nltk.stem import WordNetLemmatizer

# %%
#Load required libraries
import pandas as pd
import string
import io
import requests
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import re

# %%
#Load the dataset from Google Sheets

dataset_url = "https://docs.google.com/spreadsheets/d/1CsHU2LBuxlckPZD1EiOL0TV21XV3DGo5m9cj8ZpFy4A/edit?usp=sharing"

# Convert the Google Sheet URL to CSV format
csv_url = dataset_url.replace('/edit?usp=sharing', '/export?format=csv')

# Download and read the dataset
response = requests.get(csv_url)
response.raise_for_status()
df = pd.read_csv(io.StringIO(response.text))
df["description"] = df["description"].astype(str)
df.head(3)
# Out:
#           isbn13   isbn10                title subtitle             authors  \
# 0  9780002005883  2005883               Gilead      NaN  Marilynne Robinson
# 1  9780006178736  6178731       Rage of angels      NaN      Sidney Sheldon
# 2  9780006482079  6482074  Warhost of Vastmark      NaN         Janny Wurts
#
#   categories                                          thumbnail  \
# 0    Fiction  http://books.google.com/books/content?id=KQZCP...
# 1    Fiction  http://books.google.com/books/content?id=FKo2T...
# 2    Fiction  http://books.google.com/books/content?id=uOL0f...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0
# 1  A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 2  Tricked once more by his wily half-brother, Ly...          1995.0
#
#    average_rating  num_pages  ratings_count
# 0            3.85      247.0          361.0
# ...

# %%
#Install and initialize PyTerrier

# !pip install python-terrier
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.0/859.0 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 39.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 47.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.9/287.9 kB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.2/119.2 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 2.5 MB/s eta 0:00:00
# ...

# %%
import pyterrier as pt

if not pt.java.started():
    pt.java.init()
# Out:
# terrier-assemblies 5.11 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.8 jar not found, downloading to /root/.pyterrier...
# Done
# Java started and loaded: pyterrier.java, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

#Download NLTK resources for text processing
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')

# Define stopword
stop_words=stopwords.words('english')
# Define lemma function
wnl = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %% [markdown]
# # **Part 1: Data Preprocessing [1 mark]**

# %%
# [1 mark] Define the text preprocessing function:
from nltk.stem import WordNetLemmatizer

def preprocess(text):

    """Preprocesses text by:
    - Lowercasing
    - Removing punctuation, parantheses\brackets, and URLs
    - Tokenizing
    - Removing stopwords
    - Applying lemmatization
    """
    # Write your code
    text = text.lower()
    text = re.sub(r'\[.*?\]|https?://\S+|www\.\S+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return " ".join(tokens)



# Apply preprocessing to product names and reviews:

df['processed_description'] = df['description'].apply(preprocess)

df.head()
# Out:
#           isbn13      isbn10                              title subtitle  \
# 0  9780002005883     2005883                             Gilead      NaN
# 1  9780006178736     6178731                     Rage of angels      NaN
# 2  9780006482079     6482074                Warhost of Vastmark      NaN
# 3  9780006646006  000664600X                 Ocean Star Express      NaN
# 4  9780006906018  000690601X  The Princess of the Chalet School      NaN
#
#                     authors        categories  \
# 0        Marilynne Robinson           Fiction
# 1            Sidney Sheldon           Fiction
# 2               Janny Wurts           Fiction
# 3  Mark Haddon;Peter Sutton  Juvenile Fiction
# 4    Elinor Mary Brent-Dyer  Juvenile Fiction
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=FKo2T...
# 2  http://books.google.com/books/content?id=uOL0f...
# ...

# %% [markdown]
# # **Part 2: Indexing with PyTerrier [1.5 mark]**

# %% [markdown]
# ##CODE

# %%
# [ 1 mark ] Index book description texts using PyTerrier
# Initialize PyTerrier
if not pt.java.started():
    pt.java.init()
# Convert DataFrame to PyTerrier format (Create 'docno' column)
df["docno"] = list(range(df.shape[0]))
df["docno"] = df["docno"].astype(str)

# Create index
indexer = pt.IterDictIndexer("./index_books")
index_ref = indexer.index(df[['docno', 'processed_description']].to_dict(orient='records'))
index = pt.IndexFactory.of(index_ref)



print(index_ref.toString())
# Out:
# Exception in thread Thread-8 (_write_fifos):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/pyterrier/terrier/index.py", line 795, in _write_fifos
#     for doc in it:
#   File "/usr/local/lib/python3.11/dist-packages/pyterrier/terrier/index.py", line 616, in <genexpr>
#     return ({f: doc[f] for f in all_cols} for doc in it)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pyterrier/terrier/index.py", line 616, in <dictcomp>
#     return ({f: doc[f] for f in all_cols} for doc in it)
#                 ~~~^^^
# KeyError: 'text'
# ---------------------------------------------------------------------------
# JavaException                             Traceback (most recent call last)
# ...

# %%
for x in index_description.getLexicon():
  print("%s : %s " % (x.getKey(), x.getValue().toString()))

# %%
# [ 0.5 mark ] Define the search function:

def search_term(index, query):
    """Searches for a query in the given index."""

    # Write your code
    p = pt.BatchRetrieve(index, wmodel="BM25")
    results = p.search(query)
    return results[['docno', 'score']]

# %% [markdown]
# # **Part 3: Perform queries on the sentence index** [1.5 mark]

# %%
# Execute queries
queries = ["Theory of Relativity", "love story", "motive"]
query_results = {query: search_term(index, query) for query in queries}

# %%
#Identify Most Frequent Words in Reviews:
from collections import Counter



all_words = " ".join(df['processed_description']).split()
word_freq = Counter(all_words)

# %% [markdown]
# # **Part 4: Book Recommendation** [1 mark]

# %%
import re

# Define list of known book categories

categories = ["science fiction", "romance", "history", "social science", "mystery"]
category_pattern = "|".join(categories)



# Function to recommend book
def recommend_book(query):
 # Write your code
    match = re.search(category_pattern, query, re.IGNORECASE)
    if match:
        category = match.group()
        recommendations = df[df["categories"].str.contains(category, case=False, na=False)][["title", "categories"]]
        return recommendations.head(5)
    return "we didn't find any thing."


query1 = "I'm looking for popular books in social science by the author John Doe"
query2 = "Science fiction is the most entertaining in the history"

recommendations1 = recommend_book(query1)
recommendations2 = recommend_book(query2)

# %%
recommend_book(query1)

# %%
recommend_book(query2)

# %% [markdown]
# # **📌 Submission Guidelines:**
#
# - Submit your Google Colab **(.ipynb)** file .
# - You could include **comments in the code to explain your choices**.
# - Provide **answers to all discussion** questions.
#
# ⚠️ **Before submitting on the Classroom, CALL your TA for verification!**
#
#  Good luck!
