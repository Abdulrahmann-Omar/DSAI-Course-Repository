# %%
from abc import ABC, abstractmethod

class Account(ABC):
    def __init__(self, balance=0):
        self._balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit must be positive")
        self._balance += amount

    def get_balance(self):
        return self._balance

    @abstractmethod
    def withdraw(self, amount):
        pass

# %%
class SavingsAccount(Account):
    def __init__(self, balance=0, interest_rate=0.05):
        super().__init__(balance)
        self.interest_rate = interest_rate

    def calculate_interest(self):
        return self._balance * self.interest_rate

    def withdraw(self, amount):
        raise NotImplementedError("users not allowed to saving accounts.")

# %%
class CheckingAccount(Account):
    def withdraw(self, amount):
        if amount > self._balance:
            raise ValueError("Insufficient balance")
        self._balance -= amount

# %%
savings = SavingsAccount(1000)
savings.deposit(500)
print(savings.get_balance())
print(savings.calculate_interest())
# Out:
# 1500
# 75.0

# %%
checking = CheckingAccount(500)
checking.deposit(200)
checking.withdraw(400)
print(checking.get_balance())
checking.withdraw(500)
# Out:
# 300
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-0452984e2daf> in <cell line: 5>()
#       3 checking.withdraw(400)
#       4 print(checking.get_balance())
# ----> 5 checking.withdraw(500)
#
# <ipython-input-4-819d684aaedd> in withdraw(self, amount)
#       2     def withdraw(self, amount):
#       3         if amount > self._balance:
# ----> 4             raise ValueError("Insufficient balance")
#       5         self._balance -= amount
#
# ValueError: Insufficient balance

# %%
savings = SavingsAccount(1000)
savings.withdraw(100)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-7-fa43d22669ea> in <cell line: 2>()
#       1 savings = SavingsAccount(1000)
# ----> 2 savings.withdraw(100)
#       3
#
# <ipython-input-3-ed955e7eea08> in withdraw(self, amount)
#       8
#       9     def withdraw(self, amount):
# ---> 10         raise NotImplementedError("users not allowed to saving accounts.")
#
# NotImplementedError: users not allowed to saving accounts.

# %%
checking = CheckingAccount(500)

checking.deposit(-100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-04d80a100ab8> in <cell line: 3>()
#       1 checking = CheckingAccount(500)
#       2
# ----> 3 checking.deposit(-100)
#
# <ipython-input-1-5953e4cdf1c1> in deposit(self, amount)
#       7     def deposit(self, amount):
#       8         if amount <= 0:
# ----> 9             raise ValueError("Deposit must be positive")
#      10         self._balance += amount
#      11
#
# ValueError: Deposit must be positive
