# %%
# !wget --content-disposition 'https://figshare.com/ndownloader/articles/21331143/versions/3'
# Out:
# --2025-05-09 16:22:27--  https://figshare.com/ndownloader/articles/21331143/versions/3
# Resolving figshare.com (figshare.com)... 52.49.76.148, 52.48.143.184, 54.171.30.6, ...
# Connecting to figshare.com (figshare.com)|52.49.76.148|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4796321715 (4.5G) [application/zip]
# Saving to: ‘21331143.zip’
#
# 21331143.zip        100%[===================>]   4.47G  38.8MB/s    in 2m 1s
#
# 2025-05-09 16:24:29 (37.7 MB/s) - ‘21331143.zip’ saved [4796321715/4796321715]

# %%
import zipfile
import os

zip_path = '21331143.zip'
extract_path = 'UATD_Dataset'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List extracted files
os.listdir(extract_path)
# Out:
# ['UATD_Test_2.zip', 'UATD_OpenSLT.zip', 'UATD_Test_1.zip', 'UATD_Training.zip']
